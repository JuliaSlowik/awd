# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
dane = pd.read_csv("vgsales.csv", parse_dates=['Year'])
dane
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16598 rows x 11 columns]

# %%
dane = dane.dropna() #usuwam wszytkie NaN
dane = dane.drop_duplicates() #usuwam ewentualnie występujące duplikaty
dane
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16289 rows x 11 columns]

# %%
dane.drop(columns = 'Rank', inplace = True)
#wyżej usuwam kolumnę "Rank", ponieważ stanowi jedynie kopię indeksowania wierszów, jest efektem sortowania zbioru pod względem sprzedaży globalnej i raczej nie będziemy jej używać
dane
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594                     Men in Black II: Alien Escape       GC  2003
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596                                        Know How 2       DS  2010
# 16597                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16289 rows x 10 columns]

# %%
dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16289 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16289 non-null  object
#  1   Platform      16289 non-null  object
#  2   Year          16289 non-null  object
#  3   Genre         16289 non-null  object
#  4   Publisher     16289 non-null  object
#  5   NA_Sales      16289 non-null  float64
#  6   EU_Sales      16289 non-null  float64
#  7   JP_Sales      16289 non-null  float64
#  8   Other_Sales   16289 non-null  float64
#  9   Global_Sales  16289 non-null  float64
# dtypes: float64(5), object(5)
# memory usage: 1.4+ MB

# %%
dane['Year'] = dane['Year'].astype(int)
dane['Platform'] = dane['Platform'].astype('category')
dane['Genre'] = dane['Genre'].astype('category')
dane['Publisher'] = dane['Publisher'].astype('category')
dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16289 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16289 non-null  object
#  1   Platform      16289 non-null  category
#  2   Year          16289 non-null  int64
#  3   Genre         16289 non-null  category
#  4   Publisher     16289 non-null  category
#  5   NA_Sales      16289 non-null  float64
#  6   EU_Sales      16289 non-null  float64
#  7   JP_Sales      16289 non-null  float64
#  8   Other_Sales   16289 non-null  float64
#  9   Global_Sales  16289 non-null  float64
# dtypes: category(3), float64(5), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
dane['Platform'].unique()
# Out:
# [Wii, NES, GB, DS, X360, ..., NG, TG16, 3DO, GG, PCFX]
# Length: 31
# Categories (31, object): [Wii, NES, GB, DS, ..., TG16, 3DO, GG, PCFX]

# %%
dane['Genre'].unique()
# Out:
# [Sports, Platform, Racing, Role-Playing, Puzzle, ..., Simulation, Action, Fighting, Adventure, Strategy]
# Length: 12
# Categories (12, object): [Sports, Platform, Racing, Role-Playing, ..., Action, Fighting, Adventure, Strategy]

# %%
dane['Publisher'].unique()
# Out:
# [Nintendo, Microsoft Game Studios, Take-Two Interactive, Sony Computer Entertainment, Activision, ..., Inti Creates, Takuyo, Interchannel-Holon, Rain Games, UIG Entertainment]
# Length: 576
# Categories (576, object): [Nintendo, Microsoft Game Studios, Take-Two Interactive, Sony Computer Entertainment, ..., Takuyo, Interchannel-Holon, Rain Games, UIG Entertainment]

# %%
for platform_cat in dane['Platform'].cat.categories:
    counter = 0
    for game_platform in dane['Platform']:
        if platform_cat == game_platform:
            counter += 1
    print(platform_cat,':',counter)
# Out:
# 2600 : 116
# 3DO : 3
# 3DS : 499
# DC : 52
# DS : 2131
# GB : 97
# GBA : 786
# GC : 542
# GEN : 27
# GG : 1
# N64 : 316
# NES : 98
# NG : 12
# PC : 938
# PCFX : 1
# PS : 1189
# PS2 : 2127
# PS3 : 1303
# PS4 : 336
# PSP : 1196
# PSV : 410
# SAT : 173
# SCD : 6
# SNES : 239
# TG16 : 2
# WS : 6
# Wii : 1290
# WiiU : 143
# X360 : 1234
# XB : 803
# XOne : 213

# %%
dane.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16289.000000  16289.000000  16289.000000  16289.000000  16289.000000
# mean    2006.405304      0.264763      0.147035      0.078862      0.048432
# std        5.832700      0.822388      0.509101      0.311901      0.190094
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales
# count  16289.000000
# mean       0.540969
# std        1.567432
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.480000
# max       82.740000

# %%
data = dane.groupby('Publisher').mean()
#data.drop(columns = 'Name', inplace = True)
data[data.JP_Sales>0.5]
# Out:
#                         Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Enix Corporation  1997.60000  0.025333  0.010333  1.080000     0.009000
# Nintendo          2003.83046  1.171394  0.597773  0.653721     0.136767
# Quest             1995.00000  0.000000  0.000000  0.710000     0.000000
# SquareSoft        1996.50000  0.212692  0.095192  0.771731     0.029615
# mixi, Inc         2015.00000  0.000000  0.000000  0.860000     0.000000
#
#                   Global_Sales
# Publisher
# Enix Corporation      1.124667
# Nintendo              2.563836
# Quest                 0.710000
# SquareSoft            1.108654
# mixi, Inc             0.860000

# %%
lata=dane.groupby('Year').sum()
lata
# Out:
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 1980     10.59      0.67      0.00         0.12         11.38
# 1981     33.05      1.96      0.00         0.32         35.77
# 1982     26.92      1.65      0.00         0.31         28.86
# 1983      7.76      0.80      8.10         0.14         16.79
# 1984     33.28      2.10     14.27         0.70         50.36
# 1985     33.27      4.74     14.56         0.92         53.94
# 1986     12.50      2.84     19.81         1.93         37.07
# 1987      8.46      1.41     11.63         0.20         21.74
# 1988     23.87      6.59     15.76         0.99         47.22
# 1989     45.15      8.44     18.36         1.50         73.45
# 1990     25.46      7.63     14.88         1.40         49.39
# 1991     12.76      3.95     14.78         0.74         32.23
# 1992     33.87     11.71     28.91         1.65         76.16
# 1993     14.12      4.65     25.33         0.89         45.98
# 1994     28.15     14.88     33.99         2.20         79.17
# 1995     24.82     14.71     45.75         2.64         88.11
# 1996     86.76     47.26     57.44         7.69        199.15
# 1997     94.30     48.32     48.87         9.13        200.98
# 1998    128.36     66.70     50.04        11.03        256.47
# 1999    125.61     62.67     52.34        10.05        251.27
# 2000     92.10     52.75     42.77        11.62        201.56
# 2001    173.72     94.89     40.07        22.76        331.47
# 2002    215.78    109.09     41.76        27.28        395.52
# 2003    192.97    102.37     34.43        26.01        357.85
# 2004    218.41    105.92     41.65        47.24        414.01
# 2005    241.55    121.56     54.28        40.55        458.51
# 2006    262.93    128.46     73.73        54.43        521.04
# 2007    310.43    159.75     60.21        77.58        609.84
# 2008    349.40    183.78     60.26        82.39        678.90
# 2009    338.68    190.71     61.89        74.77        667.30
# 2010    301.36    175.40     59.45        59.90        600.25
# 2011    240.25    166.36     53.04        54.39        515.80
# 2012    154.03    117.46     51.74        37.82        363.49
# 2013    154.77    123.80     47.59        39.82        368.11
# 2014    131.97    125.10     39.46        40.02        337.03
# 2015    102.38     97.21     33.72        30.01        264.44
# 2016     22.66     26.76     13.67         7.75         70.90
# 2017      0.00      0.00      0.05         0.00          0.05
# 2020      0.27      0.00      0.00         0.02          0.29

# %%
grupy=[['1980-1989'],['1990-1999'],['2000-2009'],['2010-2020']]
gen = iter(range(4))
for i in range(1980,2020,10):
    grupy[next(gen)].append(sum(lata.Global_Sales.loc[i:i+9]))
grupy[3][1] += lata.Global_Sales.loc[2020]
grupy=dict(grupy)
plt.xlabel('Przedziały lat')
plt.ylabel('Liczba sprzedanych gier (sztuki)')

plt.bar(grupy.keys(),grupy.values())
# Out:
# <BarContainer object of 4 artists>

# %%
grupy
# Out:
# {'1980-1989': 376.58,
#  '1990-1999': 1278.9099999999999,
#  '2000-2009': 4635.999999999967,
#  '2010-2020': 2520.3599999999856}

# %%
# Out:
#          Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 1994   121896      1.76      1.20      2.67         0.40          6.02
# 1995   859167     14.61      9.66      9.54         1.96         35.92
# 1996  1211028     45.42     25.92     17.82         5.54         94.68
# 1997  1234433     57.61     37.14     33.10         7.87        136.08
# 1998  1624959     83.22     48.54     28.48         9.05        169.58
# 1999  1263343     65.49     42.60     28.07         7.92        144.57
# 2000  1600165     60.82     41.18     23.47         8.86        135.39
# 2001  1876081     95.07     66.09     21.86        18.95        201.95
# 2002  2008362     99.32     67.16     23.49        22.08        212.09
# 2003  1449129     84.69     61.98     19.11        20.83        186.34
# 2004  1708653     98.64     57.73     21.20        40.94        218.91
# 2005  2452023    110.05     50.77     18.28        25.71        204.88
# 2006  4523650     86.56     42.90     23.10        27.07        180.34
# 2007  3698620     82.39     51.39     19.74        43.40        197.21
# 2008  3433201     89.00     55.30     21.63        41.15        208.20
# 2009  3440926     84.43     57.85     19.16        34.87        196.86
# 2010  3637795     70.51     59.65     28.70        26.29        185.12
# 2011  3251823     68.14     61.58     28.56        24.11        182.88
# 2012  2826517     46.85     46.98     21.57        20.31        135.74
# 2013  2235057     54.89     58.11     20.03        24.09        158.03
# 2014  2569061     53.42     68.85     15.44        27.08        164.70
# 2015  3383659     45.62     59.14     14.75        20.69        140.74
# 2016  2285326     12.45     18.58      8.11         6.09         45.24
# 2017    47078      0.00      0.00      0.05         0.00          0.05

# %%
dane['Platform'].unique()
# Out:
# [Wii, NES, GB, DS, X360, ..., NG, TG16, 3DO, GG, PCFX]
# Length: 31
# Categories (31, object): [Wii, NES, GB, DS, ..., TG16, 3DO, GG, PCFX]

# %%
uc = set(dane['Platform'])
print(uc)
# Out:
# {'SCD', 'PCFX', 'SAT', 'DC', 'N64', 'DS', 'NES', 'GG', 'SNES', 'GEN', 'PS3', 'PS2', 'Wii', 'TG16', 'PSV', 'X360', 'PSP', 'WiiU', 'GBA', 'PC', '2600', 'PS', 'XOne', 'NG', 'XB', 'GB', '3DS', '3DO', 'GC', 'PS4', 'WS'}

# %%
uc=set(dane['Publisher'])
print(uc)
# Out:
# {'Cygames', 'Her Interactive', 'From Software', 'Paradox Development', 'Unknown', 'Screenlife', 'Hearty Robin', 'Psygnosis', 'Little Orbit', 'Flight-Plan', '20th Century Fox Video Games', 'Majesco Entertainment', 'Sony Computer Entertainment Europe', 'Xseed Games', 'Paon Corporation', 'Tradewest', 'Telegames', 'Nobilis', 'Big Ben Interactive', 'Insomniac Games', 'Avanquest Software', 'RedOctane', 'Nihon Falcom Corporation', 'Commseed', 'Extreme Entertainment Group', 'TopWare Interactive', 'Men-A-Vision', 'Culture Publishers', 'Technos Japan Corporation', '505 Games', 'Asmik Corp', 'Xplosiv', 'Sonnet', 'Micro Cabin', 'GungHo', 'Fox Interactive', 'Legacy Interactive', 'Societa', 'Media Works', 'FuRyu Corporation', 'Virgin Interactive', 'Video System', 'Tivola', 'Indie Games', 'Mamba Games', 'Visco', 'Hudson Soft', 'Starpath Corp.', 'Hudson Entertainment', 'Nitroplus', 'New World Computing', 'Michaelsoft', 'Office Create', 'Midway Games', 'Crave Entertainment', 'Nippon Ichi Software', 'Media Entertainment', 'Rocket Company', 'Namco Bandai Games', 'BushiRoad', 'DreamWorks Interactive', 'Hasbro Interactive', 'PQube', 'Mystique', 'Rage Software', 'Nintendo', 'ASK', 'Glams', 'Vivendi Games', 'Universal Gamex', 'BPS', 'Introversion Software', 'Kadokawa Shoten', 'Falcom Corporation', 'Ongakukan', 'Ackkstudios', 'Creative Core', 'General Entertainment', 'Abylight', 'NDA Productions', 'Saurus', 'Activision Value', 'Team17 Software', 'Imageworks', 'Pack-In-Video', 'Scholastic Inc.', 'Activision Blizzard', 'The Adventure Company', 'Bohemia Interactive', 'Slightly Mad Studios', 'O3 Entertainment', 'Big Fish Games', 'Edia', 'LSP Games', 'Essential Games', 'Sunflowers', 'ASC Games', 'Boost On', 'Riverhillsoft', 'Foreign Media Games', 'Warp', 'Imagineer', 'Coleco', 'Rebellion Developments', 'NetRevo', 'Asylum Entertainment', 'Merscom LLC', 'Ascaron Entertainment GmbH', 'Gremlin Interactive Ltd', 'Enjoy Gaming ltd.', 'Mastiff', 'Interplay Productions', 'Sony Online Entertainment', 'Lexicon Entertainment', 'Benesse', 'Detn8 Games', 'Fields', 'CPG Products', 'Axela', 'Kando Games', '3DO', 'Pinnacle', 'Gathering of Developers', 'Kalypso Media', 'Magical Company', 'Mojang', 'Pacific Century Cyber Works', 'Licensed 4U', 'Views', 'D3Publisher', 'Aspyr', 'SPS', 'Intergrow', 'Touchstone', 'Game Factory', 'Yamasa Entertainment', 'Quest', 'BMG Interactive Entertainment', 'NovaLogic', 'Gamebridge', 'Takara Tomy', 'Microids', 'Kaga Create', 'Pack In Soft', 'Blast! Entertainment Ltd', 'Compile Heart', 'Take-Two Interactive', 'ValuSoft', 'Titus', 'Blue Byte', 'THQ', 'Navarre Corp', 'Level 5', 'Pony Canyon', 'Naxat Soft', 'Mitsui', 'Global Star', 'Angel Studios', 'Deep Silver', 'PopCap Games', 'Success', 'Giza10', 'Milestone', 'Graphsim Entertainment', 'Funsta', 'Cloud Imperium Games Corporation', 'Answer Software', 'Compile', 'Ocean', 'DHM Interactive', 'Brash Entertainment', 'Telltale Games', 'Interchannel', 'ASCII Entertainment', 'King Records', 'Imax', 'Phenomedia', 'JVC', 'Strategy First', 'Karin Entertainment', 'Neko Entertainment', 'Core Design Ltd.', 'Zoo Games', 'Enterbrain', 'Yumedia', 'Zushi Games', 'DigiCube', 'Aques', 'Monte Christo Multimedia', 'Marvelous Games', 'MLB.com', 'Rebellion', 'City Interactive', 'White Park Bay Software', 'Ghostlight', 'Global A Entertainment', 'P2 Games', 'Popcorn Arcade', 'Conspiracy Entertainment', 'Giga', 'Takuyo', 'SCS Software', 'Natsume', 'ITT Family Games', 'Syscom', 'Plenty', 'Wargaming.net', 'Acquire', 'Elite', 'Victor Interactive', 'Gainax Network Systems', 'Sold Out', 'KID', 'Rain Games', 'SouthPeak Games', 'Aksys Games', 'Milestone S.r.l', 'Nordcurrent', '2D Boy', 'Data East', 'Oxygen Interactive', 'BAM! Entertainment', 'HuneX', 'Ecole', 'Spike', 'G.Rev', 'IE Institute', 'Microsoft Game Studios', 'Magix', 'CBS Electronics', 'Tommo', 'Palcom', 'Hamster Corporation', 'Just Flight', 'Elf', 'HAL Laboratory', 'TDK Mediactive', 'Phoenix Games', 'Rondomedia', 'Valcon Games', 'Ignition Entertainment', 'Rising Sta ...

# %%
xbox = dane[dane['Platform'].str.contains('X')].groupby('Year').sum()
xbox
# Out:
#          Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 1996    14559      0.00      0.00      0.03         0.00          0.03
# 2000     2085      0.74      0.21      0.00         0.04          0.99
# 2001   190790     16.61      4.65      0.37         0.63         22.24
# 2002  1371621     34.05     11.78      0.49         1.69         48.15
# 2003  1666772     39.34     12.92      0.30         1.91         55.16
# 2004  1503894     48.47     14.62      0.20         2.13         65.50
# 2005  1710294     41.73     13.00      0.30         2.36         57.49
# 2006  1345255     42.63     13.37      1.20         4.78         62.03
# 2007   778334     63.36     22.70      1.52         8.76         96.39
# 2008   798972     82.57     38.68      1.89        12.70        135.94
# 2009  1168353     73.97     33.91      1.95        11.09        120.85
# 2010  1197353    106.18     46.86      2.11        14.21        171.05
# 2011  1543205     86.70     43.85      1.78        12.75        145.12
# 2012   616637     57.42     31.87      1.06         8.27        100.88
# 2013   514293     64.93     33.50      0.45         8.94        108.21
# 2014   795982     50.50     30.30      0.22         7.32         88.85
# 2015   938142     41.40     22.75      0.17         6.37         70.71
# 2016   678205      7.05      5.03      0.01         1.12         13.20

# %%
ps = dane[dane['Platform'].str.contains('PS')].groupby('Year').sum()
ps
# Out:
#          Rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 1994   121896      1.76      1.20      2.67         0.40          6.02
# 1995   859167     14.61      9.66      9.54         1.96         35.92
# 1996  1211028     45.42     25.92     17.82         5.54         94.68
# 1997  1234433     57.61     37.14     33.10         7.87        136.08
# 1998  1624959     83.22     48.54     28.48         9.05        169.58
# 1999  1263343     65.49     42.60     28.07         7.92        144.57
# 2000  1600165     60.82     41.18     23.47         8.86        135.39
# 2001  1876081     95.07     66.09     21.86        18.95        201.95
# 2002  2008362     99.32     67.16     23.49        22.08        212.09
# 2003  1449129     84.69     61.98     19.11        20.83        186.34
# 2004  1708653     98.64     57.73     21.20        40.94        218.91
# 2005  2452023    110.05     50.77     18.28        25.71        204.88
# 2006  4523650     86.56     42.90     23.10        27.07        180.34
# 2007  3698620     82.39     51.39     19.74        43.40        197.21
# 2008  3433201     89.00     55.30     21.63        41.15        208.20
# 2009  3440926     84.43     57.85     19.16        34.87        196.86
# 2010  3637795     70.51     59.65     28.70        26.29        185.12
# 2011  3251823     68.14     61.58     28.56        24.11        182.88
# 2012  2826517     46.85     46.98     21.57        20.31        135.74
# 2013  2235057     54.89     58.11     20.03        24.09        158.03
# 2014  2569061     53.42     68.85     15.44        27.08        164.70
# 2015  3383659     45.62     59.14     14.75        20.69        140.74
# 2016  2285326     12.45     18.58      8.11         6.09         45.24
# 2017    47078      0.00      0.00      0.05         0.00          0.05

# %%
ps_dict=dict(ps.loc[2000:2016,'Global_Sales'])
xbox_dict = dict(xbox.loc[2000:2016,'Global_Sales'])
plt.plot(ps_dict.keys(),ps_dict.values(),label='Playstation')
plt.plot(xbox_dict.keys(),xbox_dict.values(),label='XBOX',color='orange')
plt.title('Ilość sprzedanych gier na platformach Playstation i XBOX-porównanie')
plt.xlabel('Rok [-]')
plt.ylabel('Liczba sprzedanych egzemplarzy [-]')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-9ca785377f8f> in <module>
# ----> 1 ps_dict=dict(ps.loc[2000:2016,'Global_Sales'])
#       2 xbox_dict = dict(xbox.loc[2000:2016,'Global_Sales'])
#       3 plt.plot(ps_dict.keys(),ps_dict.values(),label='Playstation')
#       4 plt.plot(xbox_dict.keys(),xbox_dict.values(),label='XBOX',color='orange')
#       5 plt.title('Ilość sprzedanych gier na platformach Playstation i XBOX-porównanie')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1419                     return section
#    1420                 # This is an elided recursive call to iloc/loc/etc'
# -> 1421                 return getattr(section, self.name)[new_key]
#    1422
#    1423         raise IndexingError("not applicable")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1910         if isinstance(key, slice):
#    1911             self._validate_key(key, axis)
# -> 1912             return self._get_slice_axis(key, axis=axis)
#    1913         elif com.is_bool_indexer(key):
#    1914             return self._getbool_axis(key, axis=axis)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1794
#    1795         labels = obj._get_axis(axis)
# -> 1796         indexer = labels.slice_indexer(
#    1797             slice_obj.start, slice_obj.stop, slice_obj.step, kind=self.name
#    1798         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4711         slice(1, 3)
#    4712         """
# -> 4713         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    4714
#    4715         # return a slice
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    4924         start_slice = None
#    4925         if start is not None:
# -> 4926             start_slice = self.get_slice_bound(start, "left", kind)
#    4927         if start_slice is None:
#    4928             start_slice = 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4836         # For datetime indices label may be a string that has to be converted
#    4837         # to datetime boundary according to its resolution.
# -> 4838         label = self._maybe_cast_slice_bound(label, side, kind)
#    4839
#    4840         # we need to look up the label
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    4788         # this is rejected (generally .loc gets you here)
#    4789         elif is_integer(label):
# -> 4790             self._invalid_indexer("slice", label)
#    4791
#    4792         return label
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3074         Consistent invalid indexer message.
#    3075         """
# -> 3076         raise TypeError(
#    3077             f"cannot do {form} indexing on {type(self)} with these "
#    3078             f"indexers [{key}] of {type(key)}"
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [2000] of <class 'int'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-10d4945c5916> in <module>
# ----> 1 lista_ps=list(pd.index.values)
#       2 lista_ps
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'index'
